# %% [markdown]
# <a href="https://colab.research.google.com/github/tidocr0/TH-DeepBuoi03/blob/main/THDLBuoi03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler

fashion = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion.load_data()

X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)

minmax = MinMaxScaler()
X_train = minmax.fit_transform(X_train)
X_test = minmax.transform(X_test)

fashion_model = Sequential()
fashion_model.add(Dense(input_dim=X_train.shape[1], units=256, kernel_initializer='uniform', activation='relu'))
fashion_model.add(Dense(units=10, kernel_initializer='uniform', activation='softmax'))

fashion_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_fit = fashion_model.fit(X_train, y_train, validation_split=0.1, epochs=20, verbose=1)

print(np.argmax(fashion_model.predict(X_test)[0]), y_test[0])

plt.plot(model_fit.history['accuracy'])
plt.plot(model_fit.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(model_fit.history['loss'])
plt.plot(model_fit.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8222 - loss: 0.5048 - val_accuracy: 0.8617 - val_loss: 0.3772
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8657 - loss: 0.3701 - val_accuracy: 0.8622 - val_loss: 0.3785
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8785 - loss: 0.3297 - val_accuracy: 0.8653 - val_loss: 0.3766
# Epoch 4/20
# ...

# %%
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense

fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train_raw, y_train), (X_test_raw, y_test) = fashion_mnist.load_data()

X_train = X_train_raw.reshape(-1, 784)
X_test = X_test_raw.reshape(-1, 784)

model = Sequential()
model.add(Dense(input_dim=784, units=256, kernel_initializer='uniform', activation='relu'))
model.add(Dense(units=10, kernel_initializer='uniform', activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=30, verbose=1)

print(np.argmax(model.predict(X_test)[0]), y_test[0])

img_test = X_test[0].reshape(1, 784)
img_predict = model.predict(img_test)
print(np.argmax(img_predict))
# Out:
# Epoch 1/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7926 - loss: 0.8713
# Epoch 2/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8284 - loss: 0.4909
# Epoch 3/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8337 - loss: 0.4869
# Epoch 4/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8382 - loss: 0.4769
# Epoch 5/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8402 - loss: 0.4713
# Epoch 6/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8449 - loss: 0.4523
# Epoch 7/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8476 - loss: 0.4525
# Epoch 8/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8468 - loss: 0.4503
# Epoch 9/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8473 - loss: 0.4471
# Epoch 10/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.8508 - loss: 0.4347
# Epoch 11/30
# ...

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Flatten

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
X_train = X_train / 255.0
X_test = X_test / 255.0

model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=20, validation_split=0.1)
model.save('model_ex1.h5')
# Out:
# Epoch 1/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 44s 30ms/step - accuracy: 0.3260 - loss: 1.8914 - val_accuracy: 0.3592 - val_loss: 1.7911
# Epoch 2/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.3882 - loss: 1.7062 - val_accuracy: 0.3852 - val_loss: 1.7133
# Epoch 3/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.4120 - loss: 1.6446 - val_accuracy: 0.4150 - val_loss: 1.6366
# Epoch 4/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.4277 - loss: 1.6071 - val_accuracy: 0.4208 - val_loss: 1.6391
# Epoch 5/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.4389 - loss: 1.5723 - val_accuracy: 0.4312 - val_loss: 1.5965
# Epoch 6/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 42s 24ms/step - accuracy: 0.4515 - loss: 1.5450 - val_accuracy: 0.4466 - val_loss: 1.5639
# Epoch 7/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.4568 - loss: 1.5269 - val_accuracy: 0.4406 - val_loss: 1.5639
# Epoch 8/20
# ...

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Flatten

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train / 255.0
X_test = X_test / 255.0

model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=20, validation_split=0.1)
model.save('model_ex2.h5')
# Out:
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9311 - loss: 0.2388 - val_accuracy: 0.9710 - val_loss: 0.1012
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9713 - loss: 0.0965 - val_accuracy: 0.9737 - val_loss: 0.0862
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9804 - loss: 0.0644 - val_accuracy: 0.9700 - val_loss: 0.0969
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9862 - loss: 0.0453 - val_accuracy: 0.9795 - val_loss: 0.0666
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9893 - loss: 0.0336 - val_accuracy: 0.9792 - val_loss: 0.0695
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9919 - loss: 0.0256 - val_accuracy: 0.9803 - val_loss: 0.0738
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9941 - loss: 0.0186 - val_accuracy: 0.9820 - val_loss: 0.0745
# Epoch 8/20
# ...

# %%
import os
import numpy as np
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Flatten

folder = '/content/train/'
photos, labels = list(), list()

for file in os.listdir(folder):
    output = 0.0
    if file.startswith('dog'):
        output = 1.0
    photo = load_img(folder + file, target_size=(200, 200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = np.asarray(photos) / 255.0
labels = np.asarray(labels)

model = Sequential()
model.add(Flatten(input_shape=(200, 200, 3)))
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(photos, labels, epochs=20, validation_split=0.1)
model.save('/content/model_ex3.h5')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5366/3776283268.py in <cell line: 0>()
#       8 photos, labels = list(), list()
#       9
# ---> 10 for file in os.listdir(folder):
#      11     output = 0.0
#      12     if file.startswith('dog'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/train/'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.models import Sequential
from keras.layers import Dense

df = pd.read_csv('/content/adults.csv')
df = df.dropna()

for col in df.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

scaler = StandardScaler()
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = Sequential()
model.add(Dense(64, activation='relu', input_dim=X.shape[1]))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
model.save('/content/model_ex4.h5')
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8328 - loss: 0.3635 - val_accuracy: 0.8394 - val_loss: 0.3365
# Epoch 2/20
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8471 - loss: 0.3276 - val_accuracy: 0.8429 - val_loss: 0.3338
# Epoch 3/20
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8494 - loss: 0.3225 - val_accuracy: 0.8455 - val_loss: 0.3279
# Epoch 4/20
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8510 - loss: 0.3188 - val_accuracy: 0.8398 - val_loss: 0.3292
# Epoch 5/20
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8510 - loss: 0.3165 - val_accuracy: 0.8458 - val_loss: 0.3260
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense

df = pd.read_csv('/content/cars.csv')

for col in df.columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = Sequential()
model.add(Dense(64, activation='relu', input_dim=X.shape[1]))
model.add(Dense(32, activation='relu'))
model.add(Dense(len(set(y)), activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
model.save('/content/model_ex5.h5')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.1200 - loss: 13.9753 - val_accuracy: 0.0000e+00 - val_loss: 7.7555
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.1200 - loss: 12.6784 - val_accuracy: 0.1429 - val_loss: 6.4889
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.1200 - loss: 11.4603 - val_accuracy: 0.1429 - val_loss: 5.3870
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.1200 - loss: 10.3502 - val_accuracy: 0.1429 - val_loss: 4.4663
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.0800 - loss: 9.3530 - val_accuracy: 0.1429 - val_loss: 3.6767
# ...

# %%
# !pip install pyngrok

from flask import Flask, request, render_template_string
import numpy as np
import tensorflow as tf
from keras.models import load_model
from keras.preprocessing import image
import os
from pyngrok import ngrok

ngrok.set_auth_token("3ECVHw008mure141JZ0xxtfbKZE_7dUMes29MPLJD4SRdTG1w")
public_url = ngrok.connect(5000)
print(f"Click vao link nay de mo Web: {public_url}")

app = Flask(__name__)

model_ex1 = load_model('/content/model_ex1.h5')
model_ex2 = load_model('/content/model_ex2.h5')
model_ex3 = load_model('/content/model_ex3.h5')
model_ex4 = load_model('/content/model_ex4.h5')
model_ex5 = load_model('/content/model_ex5.h5')

html = """
<!DOCTYPE html>
<html>
<body>
    <h2>Bai 1: CIFAR10</h2>
    <form action="/predict/1" method="post" enctype="multipart/form-data"><input type="file" name="file"><input type="submit" value="Upload"></form>
    <h2>Bai 2: MNIST</h2>
    <form action="/predict/2" method="post" enctype="multipart/form-data"><input type="file" name="file"><input type="submit" value="Upload"></form>
    <h2>Bai 3: Cat vs Dog</h2>
    <form action="/predict/3" method="post" enctype="multipart/form-data"><input type="file" name="file"><input type="submit" value="Upload"></form>
    <h2>Bai 4: Adult Income</h2>
    <form action="/predict/4" method="post"><input type="text" name="features" placeholder="1,2,3..."><input type="submit" value="Predict"></form>
    <h2>Bai 5: Car Evaluation</h2>
    <form action="/predict/5" method="post"><input type="text" name="features" placeholder="1,2,3..."><input type="submit" value="Predict"></form>
</body>
</html>
"""

@app.route('/')
def home():
    return render_template_string(html)

@app.route('/predict/<int:task_id>', methods=['POST'])
def predict(task_id):
    if task_id in [1, 2, 3]:
        f = request.files['file']
        filepath = os.path.join('/content/uploads', f.filename)
        os.makedirs('/content/uploads', exist_ok=True)
        f.save(filepath)
        if task_id == 1:
            img = image.load_img(filepath, target_size=(32, 32))
            x = image.img_to_array(img) / 255.0
            x = np.expand_dims(x, axis=0)
            pred = np.argmax(model_ex1.predict(x)[0])
        elif task_id == 2:
            img = image.load_img(filepath, target_size=(28, 28), color_mode="grayscale")
            x = image.img_to_array(img) / 255.0
            x = np.expand_dims(x, axis=0).reshape(1, 784)
            pred = np.argmax(model_ex2.predict(x)[0])
        elif task_id == 3:
            img = image.load_img(filepath, target_size=(200, 200))
            x = image.img_to_array(img) / 255.0
            x = np.expand_dims(x, axis=0)
            pred = np.round(model_ex3.predict(x)[0][0])
        return str(pred)
    else:
        features = request.form['features']
        data = np.array([float(i) for i in features.split(',')]).reshape(1, -1)
        if task_id == 4:
            pred = np.round(model_ex4.predict(data)[0][0])
        elif task_id == 5:
            pred = np.argmax(model_ex5.predict(data)[0])
        return str(pred)

if __name__ == '__main__':
    app.run(port=5000)
# Out:
# ...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Click vao link nay de mo Web: NgrokTunnel: "https://catnap-dainty-garnish.ngrok-free.dev" -> "http://localhost:5000"
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#  * Serving Flask app '__main__'
# ...
